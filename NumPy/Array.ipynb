# %%
import numpy as np

# %% [markdown]
# #### Bsic Array Creation

# %%
arr = np.array([1,2,3,4])
arr
# Out:
# array([1, 2, 3, 4])

# %%
a = [1,2,3,4]
a
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# #### Array Generation Function

# %% [markdown]
# #### Random Generation Function

# %% [markdown]
# #### Array Attributes

# %% [markdown]
# #### Array Methods

# %% [markdown]
# #### Reshaping and Resizing
