# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Pivot Table

# %%
data = {
    'Date': pd.date_range('2023-01-01', periods=20),
    'Product': ['A', 'B', 'C', 'D'] * 5,
    'Region': ['East', 'West', 'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West',
                'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West', 'North', 'South'],
    'Sales': np.random.randint(100, 1000, 20),
    'Units': np.random.randint(10, 100, 20),
    'Rep': ['John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary',
            'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice']
}

df = pd.DataFrame(data)

df['Month'] = df['Date'].dt.month_name()
df['Quarter'] = 'Q' + df['Date'].dt.quarter.astype(str)
df
# Out:
#          Date Product Region  Sales  Units    Rep    Month Quarter
# 0  2023-01-01       A   East    692     43   John  January      Q1
# 1  2023-01-02       B   West    703     82   Mary  January      Q1
# 2  2023-01-03       C  North    237     21    Bob  January      Q1
# 3  2023-01-04       D  South    817     83  Alice  January      Q1
# 4  2023-01-05       A   East    888     91   John  January      Q1
# 5  2023-01-06       B   West    632     80   Mary  January      Q1
# 6  2023-01-07       C  North    449     15    Bob  January      Q1
# 7  2023-01-08       D  South    688     89  Alice  January      Q1
# 8  2023-01-09       A   East    919     18   John  January      Q1
# 9  2023-01-10       B   West    382     31   Mary  January      Q1
# 10 2023-01-11       C  North    858     77    Bob  January      Q1
# 11 2023-01-12       D  South    351     77  Alice  January      Q1
# 12 2023-01-13       A   East    952     61   John  January      Q1
# 13 2023-01-14       B   West    898     93   Mary  January      Q1
# 14 2023-01-15       C  North    384     47    Bob  January      Q1
# 15 2023-01-16       D  South    193     22  Alice  January      Q1
# 16 2023-01-17       A   East    578     95   John  January      Q1
# 17 2023-01-18       B   West    556     85   Mary  January      Q1
# 18 2023-01-19       C  North    137     82    Bob  January      Q1
# 19 2023-01-20       D  South    404     55  Alice  January      Q1

# %%
pd.pivot_table(df,values = "Sales", index = "Region", columns= "Product")
# Out:
# Product      A      B      C      D
# Region
# East     805.8    NaN    NaN    NaN
# North      NaN    NaN  413.0    NaN
# South      NaN    NaN    NaN  490.6
# West       NaN  634.2    NaN    NaN

# %%
pd.pivot_table(df,values = "Sales", index = "Region", columns= "Product", aggfunc = 'median')   # use aggrigation function median
# Out:
# Product      A      B      C      D
# Region
# East     888.0    NaN    NaN    NaN
# North      NaN    NaN  384.0    NaN
# South      NaN    NaN    NaN  404.0
# West       NaN  632.0    NaN    NaN

# %%
pivot2 = pd.pivot_table(df, values=['Sales', 'Units'], index='Region', columns='Product')
pivot2
# Out:
#          Sales                      Units
# Product      A      B      C      D     A     B     C     D
# Region
# East     805.8    NaN    NaN    NaN  61.6   NaN   NaN   NaN
# North      NaN    NaN  413.0    NaN   NaN   NaN  48.4   NaN
# South      NaN    NaN    NaN  490.6   NaN   NaN   NaN  65.2
# West       NaN  634.2    NaN    NaN   NaN  74.2   NaN   NaN

# %% [markdown]
# #### Cross Tabs

# %%
pd.crosstab(df['Region'],df['Product'])     # Cross Tab is used for counting puspose
# Out:
# Product  A  B  C  D
# Region
# East     5  0  0  0
# North    0  0  5  0
# South    0  0  0  5
# West     0  5  0  0
